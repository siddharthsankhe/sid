# %%
import nltk
import urllib
import bs4 as bs
import re
from gensim.models import Word2Vec
from nltk.corpus import stopwords
nltk.download('stopwords')
source = urllib.request.urlopen('https://en.wikipedia.org/wiki/Global_warming').read()

soup = bs.BeautifulSoup(source,'lxml')

text = ""
for paragraph in soup.find_all('p'):
    text += paragraph.text

text = re.sub(r'\[[0-9]*\]',' ',text)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)
text = re.sub(r'\s+',' ',text)
text = re.sub(r'\s+',' ',text)
text =re.sub(r'[^\w\d\s]+', '', text)

sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]
    
    
model = Word2Vec(sentences, min_count=1)

words = model.wv.vocab

vector = model.wv['global']

similar = model.wv.most_similar('global')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
words
# Out:
# {'global': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004400>,
#  'warming': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004470>,
#  'longterm': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004518>,
#  'rise': <gensim.models.keyedvectors.Vocab at 0x7fc3f00045c0>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x7fc3f00045f8>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004668>,
#  'earths': <gensim.models.keyedvectors.Vocab at 0x7fc3f00046a0>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004710>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004748>,
#  'aspect': <gensim.models.keyedvectors.Vocab at 0x7fc3f00047b8>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004828>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7fc3f00048d0>,
#  'measurements': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004908>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7fc3f00049e8>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004a20>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004a58>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004a90>,
#  'refers': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004b00>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004b38>,
#  'humancaused': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004b70>,
#  'observed': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004c18>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004cc0>,
#  'preindustrial': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004cf8>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004d30>,
#  'projected': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004da0>,
#  'continuation': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004dd8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004e48>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004f98>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fc3f0004fd0>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005080>,
#  'periods': <gensim.models.keyedvectors.Vocab at 0x7fc3f00050f0>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005128>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005160>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x7fc3f00051d0>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005208>,
#  'interchangeably': <gensim.models.keyedvectors.Vocab at 0x7fc3f00052b0>,
#  'includes': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005390>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005438>,
#  'precipitation': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005470>,
#  'impacts': <gensim.models.keyedvectors.Vocab at 0x7fc3f00054a8>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x7fc3f00054e0>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005550>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005588>,
#  'unprecedented': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005668>,
#  'instrumental': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005710>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005780>,
#  'historical': <gensim.models.keyedvectors.Vocab at 0x7fc3f00057b8>,
#  'paleoclimate': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005828>,
#  'proxy': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005898>,
#  'records': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005908>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005940>,
#  'millions': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005978>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005a58>,
#  'intergovernmental': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005b70>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005ba8>,
#  'ipcc': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005c18>,
#  'fifth': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005c50>,
#  'assessment': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005c88>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005d30>,
#  'concluded': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005dd8>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005e48>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005eb8>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005ef0>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005f28>,
#  'dominant': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005f60>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005f98>,
#  'mid': <gensim.models.keyedvectors.Vocab at 0x7fc3f0005fd0>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007048>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007080>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x7fc3f00070f0>,
#  'emission': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007160>,
#  'greenhouse': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007198>,
#  'gases': <gensim.models.keyedvectors.Vocab at 0x7fc3f00071d0>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007208>,
#  'dioxide': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007240>,
#  'methane': <gensim.models.keyedvectors.Vocab at 0x7fc3f00072b0>,
#  'nitrous': <gensim.models.keyedvectors.Vocab at 0x7fc3f00072e8>,
#  'oxide': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007390>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7fc3f00073c8>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007400>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007438>,
#  'causing': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007470>,
#  'phenomenon': <gensim.models.keyedvectors.Vocab at 0x7fc3f00074e0>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007518>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007630>,
#  'anthropogenic': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007668>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7fc3f00077f0>,
#  'projections': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007828>,
#  'summarized': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007860>,
#  'indicated': <gensim.models.keyedvectors.Vocab at 0x7fc3f00078d0>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007908>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x7fc3f00079b0>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7fc3f00079e8>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007a20>,
#  'depending': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007a90>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007b00>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007b38>,
#  'emissions': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007b70>,
#  'findings': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007be0>,
#  'recognized': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007c18>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007c50>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007cc0>,
#  'academies': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007cf8>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007d68>,
#  'industrialized': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007da0>,
#  'nations': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007eb8>,
#  'disputed': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007f98>,
#  'scientific': <gensim.models.keyedvectors.Vocab at 0x7fc3f0007fd0>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7fc3eff880f0>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88160>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88208>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88278>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7fc3eff882b0>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88320>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88390>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88400>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x7fc3eff884a8>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x7fc3eff884e0>,
#  'acidification': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88518>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x7fc3eff885c0>,
#  'expansion': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88748>,
#  'deserts': <gensim.models.keyedvectors.Vocab at 0x7fc3eff887b8>,
#  'subtropics': <gensim.models.keyedvectors.Vocab at 0x7fc3eff887f0>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88828>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88860>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88898>,
#  'oceans': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88908>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x7fc3eff889b0>,
#  'arctic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88a58>,
#  'continuing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88ac8>,
#  'retreat': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88b00>,
#  'glaciers': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88b38>,
#  'permafrost': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88be0>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88c88>,
#  'predicted': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88cf8>,
#  'frequent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88d68>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88da0>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88dd8>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88eb8>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88ef0>,
#  'waves': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88f60>,
#  'droughts': <gensim.models.keyedvectors.Vocab at 0x7fc3eff88f98>,
#  'wildfires': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89048>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89080>,
#  'rainfall': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89128>,
#  'floods': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89160>,
#  'snowfall': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89198>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89240>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89320>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89358>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89390>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89438>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89470>,
#  'decreasing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff894e0>,
#  'crop': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89588>,
#  'yields': <gensim.models.keyedvectors.Vocab at 0x7fc3eff895c0>,
#  'abandonment': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89630>,
#  'populated': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89668>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89710>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89828>,
#  'environmental': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89860>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89978>,
#  'extinction': <gensim.models.keyedvectors.Vocab at 0x7fc3eff899b0>,
#  'relocation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89a20>,
#  'ecosystems': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89a90>,
#  'adapt': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89b38>,
#  'coral': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89b70>,
#  'reefs': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89ba8>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89be0>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89c88>,
#  'threatened': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89cc0>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89d30>,
#  'inertia': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89da0>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89dd8>,
#  'atmosphere': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89e48>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89ef0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89f98>,
#  'climatic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff89fd0>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b080>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b0f0>,
#  'pronounced': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b160>,
#  'centuries': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b198>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b2b0>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b358>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b3c8>,
#  'societal': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b400>,
#  'responses': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b470>,
#  'mitigation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b5f8>,
#  'reduction': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b668>,
#  'adaptation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b6a0>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b6d8>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b748>,
#  'resilient': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b780>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b860>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b898>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b940>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b978>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8b9b0>,
#  'convention': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ba90>,
#  'unfccc': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bb38>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bb70>,
#  'ultimate': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bba8>,
#  'objective': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bbe0>,
#  'prevent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bcc0>,
#  'dangerous': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bd68>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bda0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8be10>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8be80>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bef0>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8bfd0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c160>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c198>,
#  'levelsb': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c1d0>,
#  'efforts': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c208>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c278>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c2b0>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c320>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c3c8>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c400>,
#  'feasibility': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c470>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c4a8>,
#  'scenarios': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c4e0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c588>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c5c0>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c6a0>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c6d8>,
#  'reactions': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c710>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c780>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c7f0>,
#  'pew': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c8d0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c908>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c940>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8c9e8>,
#  'median': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ca20>,
#  'respondents': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cac8>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cb00>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cba8>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cbe0>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cc18>,
#  'differences': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cc88>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ccf8>,
#  'americans': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cda0>,
#  'chinese': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ce10>,
#  'economies': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ce48>,
#  'responsible': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ce80>,
#  'annual': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ceb8>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cf60>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8cf98>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e048>,
#  'concerned': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e080>,
#  'independently': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e128>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e160>,
#  'datasets': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e198>,
#  'confirm': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e358>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e3c8>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e4e0>,
#  'doubled': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e518>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e588>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e5c0>,
#  'proxies': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e668>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e748>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e780>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e898>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e908>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e940>,
#  'regionally': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8e9b0>,
#  'varying': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ea58>,
#  'fluctuations': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8eba8>,
#  'medieval': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ebe0>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ec50>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ecc0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8eda0>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8edd8>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ee48>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ee80>,
#  'nearsurface': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ef28>,
#  'atmospheric': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ef60>,
#  'track': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8efd0>,
#  'additional': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f048>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f0f0>,
#  'stored': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f160>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f198>,
#  'accumulated': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f208>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f2b0>,
#  'melted': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f320>,
#  'warmed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f390>,
#  'continents': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f3c8>,
#  'evident': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f438>,
#  'consistent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f4a8>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f518>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f550>,
#  'observations': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f588>,
#  'documented': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f5c0>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f6d8>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f748>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f7b8>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f828>,
#  'widespread': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f8d0>,
#  'melting': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f978>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8f9e8>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fa90>,
#  'humidity': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fac8>,
#  'timing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fb38>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fb70>,
#  'eg': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fbe0>,
#  'flowering': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fc18>,
#  'plants': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fd68>,
#  'averages': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fe10>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fe80>,
#  'temperatures': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8fef0>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ff28>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ff98>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x7fc3eff8ffd0>,
#  'capacity': <gensim.models.keyedvectors.Vocab at 0x7fc3eff900b8>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90198>,
#  'evaporation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff901d0>,
#  'poles': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90278>,
#  'heated': <gensim.models.keyedvectors.Vocab at 0x7fc3eff902b0>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x7fc3eff902e8>,
#  'equatorial': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90320>,
#  'regions': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90358>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x7fc3eff903c8>,
#  'disappear': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90438>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fc3eff904a8>,
#  'reducing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90550>,
#  'reflectivity': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90588>,
#  'polar': <gensim.models.keyedvectors.Vocab at 0x7fc3eff905c0>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x7fc3eff906a0>,
#  'redistribution': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90710>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7fc3eff907b8>,
#  'amplification': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90860>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90908>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90940>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90978>,
#  'persist': <gensim.models.keyedvectors.Vocab at 0x7fc3eff909b0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7fc3eff909e8>,
#  'diffuse': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90a20>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90a58>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90ac8>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90b00>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90b70>,
#  'hemisphere': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90be0>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90c18>,
#  'pole': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90c88>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90cc0>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90d30>,
#  'arrangement': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90d68>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90e10>,
#  'resulted': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90ef0>,
#  'maximum': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90f28>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90f98>,
#  'flipping': <gensim.models.keyedvectors.Vocab at 0x7fc3eff90fd0>,
#  'reflective': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91080>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91128>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91240>,
#  'surfaces': <gensim.models.keyedvectors.Vocab at 0x7fc3eff912b0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fc3eff912e8>,
#  'thermal': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91400>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91470>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x7fc3eff914a8>,
#  'adjust': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91550>,
#  'recordbreaking': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91588>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x7fc3eff915f8>,
#  'considerable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91668>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x7fc3eff916a0>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91710>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91748>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91780>,
#  'trend': <gensim.models.keyedvectors.Vocab at 0x7fc3eff917f0>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91828>,
#  'shortterm': <gensim.models.keyedvectors.Vocab at 0x7fc3eff918d0>,
#  'overlay': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91940>,
#  'trends': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91978>,
#  'temporarily': <gensim.models.keyedvectors.Vocab at 0x7fc3eff919b0>,
#  'mask': <gensim.models.keyedvectors.Vocab at 0x7fc3eff919e8>,
#  'magnify': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91a58>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91b38>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91b70>,
#  'slower': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91be0>,
#  'dubbed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91c18>,
#  'hiatus': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91c50>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91d68>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91dd8>,
#  'storage': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91e10>,
#  'continued': <gensim.models.keyedvectors.Vocab at 0x7fc3eff91eb8>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93048>,
#  'steadily': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93080>,
#  'upwards': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93160>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff931d0>,
#  'spiked': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93240>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x7fc3eff933c8>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93400>,
#  'incorporating': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93470>,
#  'heating': <gensim.models.keyedvectors.Vocab at 0x7fc3eff934a8>,
#  'cooling': <gensim.models.keyedvectors.Vocab at 0x7fc3eff934e0>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93518>,
#  'niño': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93668>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7fc3eff936d8>,
#  'nina': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93748>,
#  'sunspot': <gensim.models.keyedvectors.Vocab at 0x7fc3eff937b8>,
#  'cycles': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93828>,
#  'volcanic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff938d0>,
#  'eruptions': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93908>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93940>,
#  'stratosphere': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93978>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7fc3eff939b0>,
#  'generate': <gensim.models.keyedvectors.Vocab at 0x7fc3eff939e8>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93a90>,
#  'decades': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93ac8>,
#  'emanate': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93b00>,
#  'socalled': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93b70>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93c18>,
#  'forcings': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93c50>,
#  'necessarily': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93c88>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93cc0>,
#  'composition': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93d30>,
#  'concentrations': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93dd8>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93e10>,
#  'luminosity': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93ef0>,
#  'variations': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93f60>,
#  'orbit': <gensim.models.keyedvectors.Vocab at 0x7fc3eff93fd0>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94048>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7fc3eff940b8>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7fc3eff940f0>,
#  'absorption': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94128>,
#  'infrared': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94160>,
#  'radiation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94198>,
#  'planets': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94208>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x7fc3eff942b0>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94320>,
#  'joseph': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94390>,
#  'fourier': <gensim.models.keyedvectors.Vocab at 0x7fc3eff943c8>,
#  'discovered': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94400>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7fc3eff944a8>,
#  'tyndall': <gensim.models.keyedvectors.Vocab at 0x7fc3eff944e0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94518>,
#  'investigated': <gensim.models.keyedvectors.Vocab at 0x7fc3eff945c0>,
#  'quantitatively': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94630>,
#  'svante': <gensim.models.keyedvectors.Vocab at 0x7fc3eff946a0>,
#  'arrhenius': <gensim.models.keyedvectors.Vocab at 0x7fc3eff946d8>,
#  'hypothesis': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94710>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94748>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94780>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x7fc3eff947b8>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94860>,
#  'description': <gensim.models.keyedvectors.Vocab at 0x7fc3eff948d0>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94908>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94940>,
#  'stewart': <gensim.models.keyedvectors.Vocab at 0x7fc3eff949e8>,
#  'callendar': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94a20>,
#  'containing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94a58>,
#  'naturally': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94a90>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94ac8>,
#  'amounts': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94b00>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94b38>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94be0>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94c50>,
#  'warmer': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94cc0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94dd8>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94e48>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94e80>,
#  'freezing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94ef0>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94f28>,
#  'vapour': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94f60>,
#  'ch': <gensim.models.keyedvectors.Vocab at 0x7fc3eff94f98>,
#  'ozone': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95048>,
#  'industrial': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95080>,
#  'revolution': <gensim.models.keyedvectors.Vocab at 0x7fc3eff950b8>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95160>,
#  'radiative': <gensim.models.keyedvectors.Vocab at 0x7fc3eff951d0>,
#  'forcing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff952b0>,
#  'tropospheric': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95320>,
#  'cfcs': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95358>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95390>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95400>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x7fc3eff954a8>,
#  'respectively': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95550>,
#  'reliable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff955c0>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7fc3eff955f8>,
#  'extracted': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95630>,
#  'cores': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95748>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95828>,
#  'geological': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95898>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95908>,
#  'indicates': <gensim.models.keyedvectors.Vocab at 0x7fc3eff959e8>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95a20>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95a58>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95ac8>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95b38>,
#  'fossil': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95b70>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95be0>,
#  'burning': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95c50>,
#  'threequarters': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95d68>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95e10>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95e80>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95eb8>,
#  'landuse': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95ef0>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95f60>,
#  'deforestation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff95fd0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97048>,
#  'nonfuel': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97080>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x7fc3eff970f0>,
#  'calcination': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97160>,
#  'limestone': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97208>,
#  'clinker': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97240>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97278>,
#  'chemical': <gensim.models.keyedvectors.Vocab at 0x7fc3eff972e8>,
#  'releases': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97320>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7fc3eff973c8>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97438>,
#  'cement': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97470>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x7fc3eff974e0>,
#  'feared': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97518>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97550>,
#  'estimates': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97668>,
#  'combustion': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97748>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97780>,
#  'flaring': <gensim.models.keyedvectors.Vocab at 0x7fc3eff977b8>,
#  'billion': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97860>,
#  'tonnes': <gensim.models.keyedvectors.Vocab at 0x7fc3eff979e8>,
#  'pgc': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97a20>,
#  'coal': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97a58>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97a90>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97ac8>,
#  'readings': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97b38>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97ba8>,
#  'worlds': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97be0>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97c88>,
#  'benchmark': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97cf8>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97d30>,
#  'mauna': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97d68>,
#  'loa': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97e10>,
#  'surpassed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97e80>,
#  'ppm': <gensim.models.keyedvectors.Vocab at 0x7fc3eff97f98>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98048>,
#  'brian': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98080>,
#  'hoskins': <gensim.models.keyedvectors.Vocab at 0x7fc3eff980b8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fc3eff980f0>,
#  'monthly': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98198>,
#  'exceeded': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98208>,
#  'march': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98240>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7fc3eff982b0>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98358>,
#  'november': <gensim.models.keyedvectors.Vocab at 0x7fc3eff983c8>,
#  'nasa': <gensim.models.keyedvectors.Vocab at 0x7fc3eff984a8>,
#  'humanmade': <gensim.models.keyedvectors.Vocab at 0x7fc3eff984e0>,
#  'continues': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98518>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98588>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7fc3eff985f8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98630>,
#  'released': <gensim.models.keyedvectors.Vocab at 0x7fc3eff986a0>,
#  'fuels': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98748>,
#  'absorbed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98780>,
#  'vegetation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98860>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98908>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7fc3eff989e8>,
#  'twentieth': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98a20>,
#  'gross': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98a58>,
#  'domestic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98a90>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98b38>,
#  'capita': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98b70>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98ba8>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98be0>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98cf8>,
#  'drivers': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98da0>,
#  'attributed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98e10>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98e48>,
#  'attributions': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98e80>,
#  'uncertainty': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98eb8>,
#  'depend': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98f60>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x7fc3eff98f98>,
#  'uncertain': <gensim.models.keyedvectors.Vocab at 0x7fc3eff990b8>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99198>,
#  'sociological': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99240>,
#  'technological': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99278>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x7fc3eff992e8>,
#  'developments': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99400>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99438>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99470>,
#  'abundant': <gensim.models.keyedvectors.Vocab at 0x7fc3eff994e0>,
#  'combined': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99518>,
#  'modelling': <gensim.models.keyedvectors.Vocab at 0x7fc3eff996a0>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99710>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99748>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7fc3eff997f0>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x7fc3eff998d0>,
#  'sres': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99940>,
#  'marker': <gensim.models.keyedvectors.Vocab at 0x7fc3eff999e8>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99a20>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99a90>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99b00>,
#  'dimming': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99b38>,
#  'gradual': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99b70>,
#  'sunlight': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99be0>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99c50>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99c88>,
#  'liquid': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99d30>,
#  'particles': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99d68>,
#  'aerosols': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99dd8>,
#  'volcanoes': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99e80>,
#  'pollutants': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99eb8>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99ef0>,
#  'exert': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99f28>,
#  'reflecting': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99f60>,
#  'incoming': <gensim.models.keyedvectors.Vocab at 0x7fc3eff99fd0>,
#  'estimating': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a080>,
#  'celsius': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a0b8>,
#  'aerosol': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a0f0>,
#  'removal': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a128>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a208>,
#  'lifetime': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a240>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a390>,
#  'stratospheric': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a400>,
#  'declining': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a438>,
#  'removing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a4e0>,
#  'masking': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a518>,
#  'providing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a5c0>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a5f8>,
#  'scattering': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a6a0>,
#  'absorbing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a6d8>,
#  'indirect': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a748>,
#  'budget': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a7f0>,
#  'sulfate': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a898>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a8d0>,
#  'cloud': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a908>,
#  'condensation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a978>,
#  'nuclei': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9a9e8>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9aa90>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ab00>,
#  'clouds': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ab38>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9aba8>,
#  'droplets': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ac50>,
#  'reflect': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9acc0>,
#  'efficiently': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9acf8>,
#  'fewer': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ad30>,
#  'twomey': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9add8>,
#  'uniform': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ae48>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ae80>,
#  'reduces': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9aeb8>,
#  'raindrops': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9af28>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9af60>,
#  'albrecht': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9afd0>,
#  'noticeable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c048>,
#  'marine': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c080>,
#  'stratiform': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c0b8>,
#  'convective': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c198>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c1d0>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c208>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c240>,
#  'soot': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c2e8>,
#  'deposited': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c320>,
#  'exacerbates': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c3c8>,
#  'limiting': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c400>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c438>,
#  'deposits': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c4e0>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c518>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c588>,
#  'suspended': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c5f8>,
#  'absorbs': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c630>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c668>,
#  'rural': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c748>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c780>,
#  'masked': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c828>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c9b0>,
#  'influences': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9c9e8>,
#  'tropics': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ca20>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ca90>,
#  'extratropics': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cac8>,
#  'irradiance': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cba8>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cbe0>,
#  'satellites': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ccf8>,
#  'examine': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cd30>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cda0>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cdd8>,
#  'reproduce': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ce80>,
#  'rapid': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9ceb8>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cef0>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9cf60>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d048>,
#  'attributable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d080>,
#  'differing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d0b8>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d0f0>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d160>,
#  'principles': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d198>,
#  'produces': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d1d0>,
#  'troposphere': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d278>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d2b0>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d320>,
#  'geologic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d400>,
#  'billions': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d438>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d4a8>,
#  'introduces': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d4e0>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d518>,
#  'cyclical': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d5f8>,
#  'tilt': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d710>,
#  'axis': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d780>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d7b8>,
#  'vary': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d7f0>,
#  'slowly': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d828>,
#  'tens': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d898>,
#  'changing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d8d0>,
#  'seasonal': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d940>,
#  'latitudinal': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9d978>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9da20>,
#  'reviewing': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9da58>,
#  'seafloor': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dac8>,
#  'sediments': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9db00>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9db38>,
#  'periodic': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dba8>,
#  'glacial': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dc50>,
#  'interglacial': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dc88>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dcc0>,
#  'contributed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dcf8>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dd30>,
#  'latitudes': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9dd68>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9de10>,
#  'reversed': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9de48>,
#  'greenhousegasinduced': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9deb8>,
#  'orbital': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9df28>,
#  'favorable': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9df60>,
#  'glaciation': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9f0b8>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9f160>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9f208>,
#  'feedbacks': <gensim.models.keyedvectors.Vocab at 0x7fc3eff9f278>,
# ...
#  'soils': <gensim.models.keyedvectors.Vocab at 0x7fc3effa03c8>,
#  'microbial': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0400>,
#  'communities': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0470>,
#  'elevated': <gensim.models.keyedvectors.Vocab at 0x7fc3effa04e0>,
#  'mechanism': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0518>,
#  'researchers': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0550>,
#  'vapor': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0588>,
#  'injected': <gensim.models.keyedvectors.Vocab at 0x7fc3effa05c0>,
#  'depletion': <gensim.models.keyedvectors.Vocab at 0x7fc3effa05f8>,
#  'subsequently': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0630>,
#  'raising': <gensim.models.keyedvectors.Vocab at 0x7fc3effa06d8>,
#  'odds': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0860>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0898>,
#  'cancer': <gensim.models.keyedvectors.Vocab at 0x7fc3effa09e8>,
#  'damaging': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0a90>,
#  'crops': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0ac8>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0b38>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0b70>,
#  'arise': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0ba8>,
#  'intensification': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0be0>,
#  'poleward': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0cc0>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0cf8>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0d68>,
#  'net': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0dd8>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0e48>,
#  'contribute': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0ef0>,
#  'circulation': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0f28>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x7fc3effa0fd0>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1080>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7fc3effa10b8>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1198>,
#  'underestimate': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1240>,
#  'studies': <gensim.models.keyedvectors.Vocab at 0x7fc3effa12b0>,
#  'linked': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1358>,
#  'rapidly': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1390>,
#  'vanishing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1438>,
#  'cryosphere': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1470>,
#  'midlatitudes': <gensim.models.keyedvectors.Vocab at 0x7fc3effa14a8>,
#  'jet': <gensim.models.keyedvectors.Vocab at 0x7fc3effa14e0>,
#  'stream': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1550>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1588>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x7fc3effa15f8>,
#  'planetary': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1630>,
#  'threshold': <gensim.models.keyedvectors.Vocab at 0x7fc3effa16a0>,
#  'selfreinforcing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1710>,
#  'manmade': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1748>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1780>,
#  'hothouse': <gensim.models.keyedvectors.Vocab at 0x7fc3effa17b8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1860>,
#  'authors': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1898>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7fc3effa18d0>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1978>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7fc3effa19b0>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1a20>,
#  'agreement': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1a90>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1b00>,
#  'coauthor': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1b38>,
#  'johan': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1ba8>,
#  'rockström': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1cc0>,
#  'notes': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1d30>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1d68>,
#  'existential': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1e10>,
#  'questions': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1eb8>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1ef0>,
#  'katherine': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1f60>,
#  'richardson': <gensim.models.keyedvectors.Vocab at 0x7fc3effa1fd0>,
#  'stresses': <gensim.models.keyedvectors.Vocab at 0x7fc3effa30b8>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3160>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3198>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7fc3effa31d0>,
#  'quasistable': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3240>,
#  'substantial': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3278>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7fc3effa32b0>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fc3effa32e8>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3358>,
#  'representation': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3390>,
#  'biological': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3400>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3470>,
#  'simplifications': <gensim.models.keyedvectors.Vocab at 0x7fc3effa34a8>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3518>,
#  'inevitable': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3588>,
#  'constraints': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3630>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3668>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x7fc3effa36d8>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3710>,
#  'limitations': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3780>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7fc3effa37b8>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3828>,
#  'inputs': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3860>,
#  'ipccs': <gensim.models.keyedvectors.Vocab at 0x7fc3effa38d0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3908>,
#  'humanitys': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3940>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x7fc3effa39e8>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3a20>,
#  'ie': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3a58>,
#  'assume': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3a90>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3ac8>,
#  'predict': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3b38>,
#  'interact': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3b70>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3ba8>,
#  'assumption': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3be0>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3c18>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3c50>,
#  'improving': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3c88>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3cf8>,
#  'topic': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3d30>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3da0>,
#  'prominent': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3dd8>,
#  'expanding': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3eb8>,
#  'representations': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3f60>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fc3effa3fd0>,
#  'investigate': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4048>,
#  'comparing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa40f0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4128>,
#  'unambiguously': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4160>,
#  'attribute': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4240>,
#  'occurred': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4278>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4320>,
#  'variation': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4400>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4518>,
#  'dominated': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4550>,
#  'realism': <gensim.models.keyedvectors.Vocab at 0x7fc3effa45f8>,
#  'tested': <gensim.models.keyedvectors.Vocab at 0x7fc3effa46a0>,
#  'examining': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4710>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4748>,
#  'simulate': <gensim.models.keyedvectors.Vocab at 0x7fc3effa47f0>,
#  'contemporary': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4828>,
#  'climates': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4898>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fc3effa48d0>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4978>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4a58>,
#  'accurately': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4ac8>,
#  'shrinkage': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4b00>,
#  'proportionally': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4b70>,
#  'hence': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4c18>,
#  'significantly': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4c50>,
#  'risen': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4c88>,
#  'considerably': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4cc0>,
#  'statespublished': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4d68>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4da0>,
#  'underestimating': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4e48>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4ef0>,
#  'relevant': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4f28>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4f60>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7fc3effa4f98>,
#  'push': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5048>,
#  'bees': <gensim.models.keyedvectors.Vocab at 0x7fc3effa50b8>,
#  'physiological': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5128>,
#  'limits': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5198>,
#  'bee': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5240>,
#  'populations': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5278>,
#  'uptake': <gensim.models.keyedvectors.Vocab at 0x7fc3effa52b0>,
#  'affects': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5320>,
#  'brains': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5358>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7fc3effa53c8>,
#  'nervous': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5400>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5470>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x7fc3effa54e0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5518>,
#  'smell': <gensim.models.keyedvectors.Vocab at 0x7fc3effa55f8>,
#  'evade': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5668>,
#  'predators': <gensim.models.keyedvectors.Vocab at 0x7fc3effa56a0>,
#  'weve': <gensim.models.keyedvectors.Vocab at 0x7fc3effa56d8>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5780>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x7fc3effa57b8>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7fc3effa57f0>,
#  'disruption': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5860>,
#  'shellfish': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5898>,
#  'plankton': <gensim.models.keyedvectors.Vocab at 0x7fc3effa59b0>,
#  'chalky': <gensim.models.keyedvectors.Vocab at 0x7fc3effa59e8>,
#  'skeletons': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5a20>,
#  'dissolved': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5a90>,
#  'fishes': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5b70>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5be0>,
#  'farreaching': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5c18>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5c50>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5cc0>,
#  'shifts': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5d30>,
#  'patterns': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5d68>,
#  'detected': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5da0>,
#  'worldwide': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5dd8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5e80>,
#  'uneven': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5eb8>,
#  'risks': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5f60>,
#  'experiencing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa5fd0>,
#  'lowlatitude': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7048>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7080>,
#  'poorer': <gensim.models.keyedvectors.Vocab at 0x7fc3effa70f0>,
#  'impaired': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7128>,
#  'previously': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7160>,
#  'islands': <gensim.models.keyedvectors.Vocab at 0x7fc3effa72b0>,
#  'mega': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7320>,
#  'deltas': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7400>,
#  'inundation': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7470>,
#  'threaten': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7550>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x7fc3effa75c0>,
#  'infrastructure': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7630>,
#  'settlements': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7668>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7780>,
#  'homelessness': <gensim.models.keyedvectors.Vocab at 0x7fc3effa77f0>,
#  'lowlying': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7860>,
#  'bangladesh': <gensim.models.keyedvectors.Vocab at 0x7fc3effa78d0>,
#  'statelessness': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7940>,
#  'maldives': <gensim.models.keyedvectors.Vocab at 0x7fc3effa79e8>,
#  'tuvalu': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7a58>,
#  'africa': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7a90>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7ac8>,
#  'megadeltas': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7b00>,
#  'affected': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7b38>,
#  'vulnerable': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7ba8>,
#  'variability': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7be0>,
#  'existing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7c18>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7c50>,
#  'adaptive': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7cf8>,
#  'poverty': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7d68>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7dd8>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7ef0>,
#  'ecosystem': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7f28>,
#  'degradation': <gensim.models.keyedvectors.Vocab at 0x7fc3effa7f98>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8048>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7fc3effa80b8>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8160>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8198>,
#  'severely': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8208>,
#  'compromise': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8240>,
#  'agricultural': <gensim.models.keyedvectors.Vocab at 0x7fc3effa82e8>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7fc3effa83c8>,
#  'projects': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8438>,
#  'uninhabitable': <gensim.models.keyedvectors.Vocab at 0x7fc3effa84e0>,
#  'wetbulb': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8518>,
#  'bears': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8588>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x7fc3effa85c0>,
#  'inhabited': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8630>,
#  'owing': <gensim.models.keyedvectors.Vocab at 0x7fc3effa86a0>,
#  'seaice': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8748>,
#  'forces': <gensim.models.keyedvectors.Vocab at 0x7fc3effa87b8>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8828>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8908>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x7fc3effa8940>,
#  ...}

# %%
vector
# Out:
# array([-2.9561594e-03, -3.3392112e-03, -7.2385662e-04, -2.2913022e-03,
#        -2.1848772e-03,  8.7284390e-04, -3.0479585e-03,  2.2132427e-03,
#         2.9938195e-03,  4.9531781e-03, -3.6328610e-03, -3.3036745e-03,
#         1.7117326e-03,  5.3387490e-04,  2.5538760e-03,  4.0561333e-03,
#        -2.6756991e-03,  2.7897358e-03,  1.4291890e-04,  4.0207119e-03,
#         1.3623168e-03, -2.9383623e-03, -2.8866888e-03,  2.6966175e-03,
#        -1.3571298e-03,  3.3455936e-03, -4.0095366e-04,  2.2302195e-03,
#         1.2342499e-03, -6.2651670e-04,  2.4429895e-04,  1.9602459e-03,
#         1.9755920e-03,  3.2981513e-03, -4.1796095e-03,  9.5878221e-04,
#        -3.8182784e-03,  4.6073790e-03,  4.5083817e-03,  1.1479072e-04,
#         3.8804356e-03, -3.3253194e-03,  2.4865270e-03, -2.3604683e-03,
#         2.6188095e-03,  4.1755023e-03,  4.1318131e-03,  2.1385362e-04,
#        -3.7843909e-04,  4.6739974e-03, -6.6351553e-04, -2.8394395e-03,
#        -1.8579866e-03, -1.0514337e-03,  9.0980873e-05,  8.2648704e-03,
#        -3.5746389e-03, -6.5870961e-04,  6.8139392e-03,  4.0222430e-03,
#        -2.4120416e-04, -2.2617807e-03,  7.9235622e-05,  8.0112269e-04,
#        -1.9926403e-03,  2.2308216e-03, -4.9027163e-03,  2.3766032e-03,
#         4.7513086e-04, -5.8813393e-03, -2.7346498e-04, -3.0776258e-03,
#         3.4114060e-03,  1.3778579e-03,  1.8732017e-03,  1.8880886e-03,
#         3.7617935e-03,  1.7552302e-03,  1.3077402e-03,  1.3922264e-03,
#        -8.1616663e-04,  2.3765077e-03,  5.4083072e-04, -1.8815371e-03,
#         2.5603052e-03,  3.6591550e-03, -1.4421721e-03,  2.2034359e-03,
#         3.3483261e-03,  4.0477011e-03, -1.2724717e-03, -3.0672157e-04,
#         9.0911047e-04, -1.8115403e-03, -8.2337698e-05,  4.8094364e-03,
#         3.1938551e-03,  4.6953280e-03, -3.4122232e-03, -2.7931470e-03],
#       dtype=float32)

# %%
similar
# Out:
# [('aerosols', 0.3956734240055084),
#  ('diffuse', 0.3266703486442566),
#  ('mass', 0.3095591366291046),
#  ('energy', 0.2869619131088257),
#  ('strong', 0.2865596115589142),
#  ('public', 0.2861614525318146),
#  ('temporarily', 0.286091685295105),
#  ('reductions', 0.2828689217567444),
#  ('range', 0.2786634564399719),
#  ('perceived', 0.27375543117523193)]

# %%
model.wv.most_similar('warming')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('due', 0.4348520040512085),
#  ('arctic', 0.33506065607070923),
#  ('since', 0.32300132513046265),
#  ('activities', 0.3216346204280853),
#  ('published', 0.31009572744369507),
#  ('normal', 0.30598029494285583),
#  ('degree', 0.2998511493206024),
#  ('developed', 0.2840769588947296),
#  ('national', 0.28199124336242676),
#  ('temperatures', 0.271088182926178)]

# %%
model.wv.most_similar(positive=['warming','temperature'], negative= ['arctic'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('heatwaves', 0.3250654935836792),
#  ('sunlight', 0.3107073903083801),
#  ('physical', 0.30259132385253906),
#  ('pronounced', 0.2933168113231659),
#  ('due', 0.2764488160610199),
#  ('makes', 0.26825079321861267),
#  ('existential', 0.2581552267074585),
#  ('developed', 0.25470954179763794),
#  ('billion', 0.2541285455226898),
#  ('projects', 0.25132399797439575)]

# %%
## using pretraind model

# %%
from gensim.models import KeyedVectors

filename = 'GoogleNews-vectors-negative300.bin'

model = KeyedVectors.load_word2vec_format(filename, binary=True)

model.wv.most_similar('king')

model.wv.most_similar(positive=['king','woman'], negative= ['man'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-a959f84f6534> in <module>()
#       3 filename = 'GoogleNews-vectors-negative300.bin'
#       4
# ----> 5 model = KeyedVectors.load_word2vec_format(filename, binary=True)
#       6
#       7 model.wv.most_similar('king')
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1436         return _load_word2vec_format(
#    1437             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1438             limit=limit, datatype=datatype)
#    1439
#    1440     def get_keras_embedding(self, train_embeddings=False):
#
# /usr/local/lib/python3.6/dist-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     169
#     170     logger.info("loading projection weights from %s", fname)
# --> 171     with utils.smart_open(fname) as fin:
#     172         header = utils.to_unicode(fin.readline(), encoding=encoding)
#     173         vocab_size, vector_size = (int(x) for x in header.split())  # throws for invalid file format
#
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     179         raise TypeError('mode should be a string')
#     180
# --> 181     fobj = _shortcut_open(uri, mode, **kw)
#     182     if fobj is not None:
#     183         return fobj
#
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, **kw)
#     299     #
#     300     if six.PY3:
# --> 301         return open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     302     elif not open_kwargs:
#     303         return open(parsed_uri.uri_path, mode, buffering=buffering)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GoogleNews-vectors-negative300.bin'
